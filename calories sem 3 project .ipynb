# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\singh\OneDrive\Documents\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df1=pd.read_csv(r"C:\Users\singh\Downloads\exercise.csv")
df1
# Out:
#         User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp
# 0      14733363    male   68   190.0    94.0      29.0       105.0       40.8
# 1      14861698  female   20   166.0    60.0      14.0        94.0       40.3
# 2      11179863    male   69   179.0    79.0       5.0        88.0       38.7
# 3      16180408  female   34   179.0    71.0      13.0       100.0       40.5
# 4      17771927  female   27   154.0    58.0      10.0        81.0       39.8
# ...         ...     ...  ...     ...     ...       ...         ...        ...
# 14995  15644082  female   20   193.0    86.0      11.0        92.0       40.4
# 14996  17212577  female   27   165.0    65.0       6.0        85.0       39.2
# 14997  17271188  female   43   159.0    58.0      16.0        90.0       40.1
# 14998  18643037    male   78   193.0    97.0       2.0        84.0       38.3
# 14999  11751526    male   63   173.0    79.0      18.0        92.0       40.5
#
# [15000 rows x 8 columns]

# %%
df2=pd.read_csv(r"C:\Users\singh\Downloads\calories.csv")
df2
# Out:
#         User_ID  Calories
# 0      14733363     231.0
# 1      14861698      66.0
# 2      11179863      26.0
# 3      16180408      71.0
# 4      17771927      35.0
# ...         ...       ...
# 14995  15644082      45.0
# 14996  17212577      23.0
# 14997  17271188      75.0
# 14998  18643037      11.0
# 14999  11751526      98.0
#
# [15000 rows x 2 columns]

# %%
df=pd.concat([df1,df2],axis=1)
df
# Out:
#         User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0      14733363    male   68   190.0    94.0      29.0       105.0       40.8
# 1      14861698  female   20   166.0    60.0      14.0        94.0       40.3
# 2      11179863    male   69   179.0    79.0       5.0        88.0       38.7
# 3      16180408  female   34   179.0    71.0      13.0       100.0       40.5
# 4      17771927  female   27   154.0    58.0      10.0        81.0       39.8
# ...         ...     ...  ...     ...     ...       ...         ...        ...
# 14995  15644082  female   20   193.0    86.0      11.0        92.0       40.4
# 14996  17212577  female   27   165.0    65.0       6.0        85.0       39.2
# 14997  17271188  female   43   159.0    58.0      16.0        90.0       40.1
# 14998  18643037    male   78   193.0    97.0       2.0        84.0       38.3
# 14999  11751526    male   63   173.0    79.0      18.0        92.0       40.5
#
#         User_ID  Calories
# ...

# %%
df=df.T.drop_duplicates().T
df
# Out:
#         User_ID  Gender Age Height Weight Duration Heart_Rate Body_Temp  \
# 0      14733363    male  68  190.0   94.0     29.0      105.0      40.8
# 1      14861698  female  20  166.0   60.0     14.0       94.0      40.3
# 2      11179863    male  69  179.0   79.0      5.0       88.0      38.7
# 3      16180408  female  34  179.0   71.0     13.0      100.0      40.5
# 4      17771927  female  27  154.0   58.0     10.0       81.0      39.8
# ...         ...     ...  ..    ...    ...      ...        ...       ...
# 14995  15644082  female  20  193.0   86.0     11.0       92.0      40.4
# 14996  17212577  female  27  165.0   65.0      6.0       85.0      39.2
# 14997  17271188  female  43  159.0   58.0     16.0       90.0      40.1
# 14998  18643037    male  78  193.0   97.0      2.0       84.0      38.3
# 14999  11751526    male  63  173.0   79.0     18.0       92.0      40.5
#
#       Calories
# 0        231.0
# 1         66.0
# 2         26.0
# 3         71.0
# 4         35.0
# ...

# %%
df2
# Out:
#         User_ID  Calories
# 0      14733363     231.0
# 1      14861698      66.0
# 2      11179863      26.0
# 3      16180408      71.0
# 4      17771927      35.0
# ...         ...       ...
# 14995  15644082      45.0
# 14996  17212577      23.0
# 14997  17271188      75.0
# 14998  18643037      11.0
# 14999  11751526      98.0
#
# [15000 rows x 2 columns]

# %%
df.head(8) #top 10 data of data set to analyze it
# Out:
#     User_ID  Gender Age Height Weight Duration Heart_Rate Body_Temp Calories
# 0  14733363    male  68  190.0   94.0     29.0      105.0      40.8    231.0
# 1  14861698  female  20  166.0   60.0     14.0       94.0      40.3     66.0
# 2  11179863    male  69  179.0   79.0      5.0       88.0      38.7     26.0
# 3  16180408  female  34  179.0   71.0     13.0      100.0      40.5     71.0
# 4  17771927  female  27  154.0   58.0     10.0       81.0      39.8     35.0
# 5  15130815  female  36  151.0   50.0     23.0       96.0      40.7    123.0
# 6  19602372  female  33  158.0   56.0     22.0       95.0      40.5    112.0
# 7  11117088    male  41  175.0   85.0     25.0      100.0      40.7    143.0

# %%
df.tail(7)
# Out:
#         User_ID  Gender Age Height Weight Duration Heart_Rate Body_Temp  \
# 14993  13584585    male  45  179.0   78.0     11.0       98.0      39.9
# 14994  18209611  female  48  159.0   57.0     10.0       94.0      39.8
# 14995  15644082  female  20  193.0   86.0     11.0       92.0      40.4
# 14996  17212577  female  27  165.0   65.0      6.0       85.0      39.2
# 14997  17271188  female  43  159.0   58.0     16.0       90.0      40.1
# 14998  18643037    male  78  193.0   97.0      2.0       84.0      38.3
# 14999  11751526    male  63  173.0   79.0     18.0       92.0      40.5
#
#       Calories
# 14993     60.0
# 14994     52.0
# 14995     45.0
# 14996     23.0
# 14997     75.0
# 14998     11.0
# 14999     98.0

# %%
df.shape
# Out:
# (15000, 9)

# %%
df.size
# Out:
# 135000

# %%
df.describe() #describe functions tells all basic important function of data set like mean,max,count,25%,50%,75% of data.
# Out:
#          User_ID  Gender    Age   Height   Weight  Duration  Heart_Rate  \
# count      15000   15000  15000  15000.0  15000.0   15000.0     15000.0
# unique     15000       2     60     90.0     91.0      30.0        59.0
# top     14733363  female     20    179.0     66.0      26.0        91.0
# freq           1    7553    512    394.0    374.0     548.0       564.0
#
#         Body_Temp  Calories
# count     15000.0   15000.0
# unique       45.0     277.0
# top          40.7       7.0
# freq       1041.0     161.0

# %%
#filling empty cells of Total_Sales with nan
df=df.replace(r'^\s*$', float(np.NaN), regex=True)
# Out:
# C:\Users\singh\AppData\Local\Temp\ipykernel_6296\928572128.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df=df.replace(r'^\s*$', float(np.NaN), regex=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   User_ID     15000 non-null  int64
#  1   Gender      15000 non-null  object
#  2   Age         15000 non-null  int64
#  3   Height      15000 non-null  float64
#  4   Weight      15000 non-null  float64
#  5   Duration    15000 non-null  float64
#  6   Heart_Rate  15000 non-null  float64
#  7   Body_Temp   15000 non-null  float64
#  8   Calories    15000 non-null  float64
# dtypes: float64(6), int64(2), object(1)
# memory usage: 1.0+ MB

# %%
df['Age'] = df['Age'].astype('Int64')
df
# Out:
#         User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0      14733363    male   68   190.0    94.0      29.0       105.0       40.8
# 1      14861698  female   20   166.0    60.0      14.0        94.0       40.3
# 2      11179863    male   69   179.0    79.0       5.0        88.0       38.7
# 3      16180408  female   34   179.0    71.0      13.0       100.0       40.5
# 4      17771927  female   27   154.0    58.0      10.0        81.0       39.8
# ...         ...     ...  ...     ...     ...       ...         ...        ...
# 14995  15644082  female   20   193.0    86.0      11.0        92.0       40.4
# 14996  17212577  female   27   165.0    65.0       6.0        85.0       39.2
# 14997  17271188  female   43   159.0    58.0      16.0        90.0       40.1
# 14998  18643037    male   78   193.0    97.0       2.0        84.0       38.3
# 14999  11751526    male   63   173.0    79.0      18.0        92.0       40.5
#
#        Calories
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   User_ID     15000 non-null  int64
#  1   Gender      15000 non-null  object
#  2   Age         15000 non-null  Int64
#  3   Height      15000 non-null  float64
#  4   Weight      15000 non-null  float64
#  5   Duration    15000 non-null  float64
#  6   Heart_Rate  15000 non-null  float64
#  7   Body_Temp   15000 non-null  float64
#  8   Calories    15000 non-null  float64
# dtypes: Int64(1), float64(6), int64(1), object(1)
# memory usage: 1.0+ MB

# %%
missing_values = df.isnull().sum() #counts the total number of nan value present in data set.
missing_values
# Out:
# User_ID       0
# Gender        0
# Age           0
# Height        0
# Weight        0
# Duration      0
# Heart_Rate    0
# Body_Temp     0
# Calories      0
# dtype: int64

# %%
plt.figure(figsize=(8,6)) #size of the figure
sns.boxplot(data=df,x="Gender", y="Calories", color="Red") #plotting the box plot for Calories vs gender.
plt.title("Calories vs Gender");

# %%
plt.figure(figsize=(8,6)) #size of the figure
sns.boxplot(data=df,x="Height", y="Calories", color="Red") #plotting the box plot for Calories vs gender.
plt.title("Calories vs Gender");

# %%
#distribution of salary on age to know the trend of salary increase according to age or not . 
plt.figure(figsize=(15,10))
plt.xlabel('Age',fontsize=15)
plt.ylabel('Calories',fontsize=15)
plt.title('Age vs Calories',fontsize=15)

sns.scatterplot(x=df['Age'],y=df['Calories'],color='blue')
plt.show()

# %%
p= df.hist(figsize=(14,14))

# %%
plt.figure(figsize=(8,5)) #size of the figure
figure=df.boxplot(column="Age") #box plot of the Age.

# %% [markdown]
# # modelling

# %%
df.replace({'male': 0, 'female': 1},
           inplace=True)
df
# Out:
# C:\Users\singh\AppData\Local\Temp\ipykernel_6296\2384826615.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace({'male': 0, 'female': 1},
#         User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0      14733363       0   68   190.0    94.0      29.0       105.0       40.8
# 1      14861698       1   20   166.0    60.0      14.0        94.0       40.3
# 2      11179863       0   69   179.0    79.0       5.0        88.0       38.7
# 3      16180408       1   34   179.0    71.0      13.0       100.0       40.5
# 4      17771927       1   27   154.0    58.0      10.0        81.0       39.8
# ...         ...     ...  ...     ...     ...       ...         ...        ...
# ...

# %%
df.drop(['User_ID'],axis=1,inplace=True)

# %%
x=df.drop(['Calories'],axis=1)
x
# Out:
#        Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp
# 0           0   68   190.0    94.0      29.0       105.0       40.8
# 1           1   20   166.0    60.0      14.0        94.0       40.3
# 2           0   69   179.0    79.0       5.0        88.0       38.7
# 3           1   34   179.0    71.0      13.0       100.0       40.5
# 4           1   27   154.0    58.0      10.0        81.0       39.8
# ...       ...  ...     ...     ...       ...         ...        ...
# 14995       1   20   193.0    86.0      11.0        92.0       40.4
# 14996       1   27   165.0    65.0       6.0        85.0       39.2
# 14997       1   43   159.0    58.0      16.0        90.0       40.1
# 14998       0   78   193.0    97.0       2.0        84.0       38.3
# 14999       0   63   173.0    79.0      18.0        92.0       40.5
#
# [15000 rows x 7 columns]

# %%
y=df['Calories']
y
# Out:
# 0        231.0
# 1         66.0
# 2         26.0
# 3         71.0
# 4         35.0
#          ...
# 14995     45.0
# 14996     23.0
# 14997     75.0
# 14998     11.0
# 14999     98.0
# Name: Calories, Length: 15000, dtype: float64

# %%
# split X and y into training and testing sets
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y,test_size = 0.3, 
                                                    random_state=0)

# %%
x_train
# Out:
#        Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp
# 10439       1   49   173.0    69.0      23.0       113.0       40.5
# 9236        1   25   173.0    62.0      16.0        91.0       40.2
# 818         1   57   167.0    68.0      18.0       114.0       40.4
# 11504       1   54   141.0    48.0      18.0       103.0       40.3
# 11722       0   54   181.0    80.0      21.0       100.0       40.5
# ...       ...  ...     ...     ...       ...         ...        ...
# 13123       0   41   179.0    83.0      26.0       107.0       40.5
# 3264        1   57   154.0    59.0       1.0        90.0       37.9
# 9845        1   36   166.0    64.0      22.0       106.0       40.6
# 10799       1   56   164.0    63.0      13.0        94.0       39.9
# 2732        0   28   166.0    66.0       2.0        72.0       38.0
#
# [10500 rows x 7 columns]

# %%
 x_test
# Out:
#        Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp
# 1670        1   27   170.0    66.0       9.0        94.0       39.8
# 13379       0   28   191.0    87.0       6.0        82.0       39.3
# 10234       1   28   197.0    87.0      22.0        95.0       40.8
# 4719        0   27   171.0    72.0      29.0       111.0       41.1
# 7003        1   79   171.0    66.0      19.0       103.0       40.1
# ...       ...  ...     ...     ...       ...         ...        ...
# 13499       1   38   165.0    61.0      20.0        99.0       40.5
# 3828        0   32   167.0    66.0      11.0        93.0       39.8
# 4645        0   29   173.0    77.0      13.0        91.0       40.0
# 6069        1   45   164.0    67.0      15.0        88.0       40.2
# 2506        0   51   184.0    92.0       3.0        80.0       38.5
#
# [4500 rows x 7 columns]

# %%
y_train
# Out:
# 10439    164.0
# 9236      71.0
# 818      133.0
# 11504    116.0
# 11722    131.0
#          ...
# 13123    175.0
# 3264       5.0
# 9845     137.0
# 10799     69.0
# 2732       1.0
# Name: Calories, Length: 10500, dtype: float64

# %%
y_test
# Out:
# 1670      43.0
# 13379     15.0
# 10234    101.0
# 4719     186.0
# 7003     126.0
#          ...
# 13499    111.0
# 3828      42.0
# 4645      47.0
# 6069      66.0
# 2506      10.0
# Name: Calories, Length: 4500, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Gender      15000 non-null  int64
#  1   Age         15000 non-null  Int64
#  2   Height      15000 non-null  float64
#  3   Weight      15000 non-null  float64
#  4   Duration    15000 non-null  float64
#  5   Heart_Rate  15000 non-null  float64
#  6   Body_Temp   15000 non-null  float64
#  7   Calories    15000 non-null  float64
# dtypes: Int64(1), float64(6), int64(1)
# memory usage: 952.3 KB

# %%
# data normalization with sklearn
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()
# fit scaler on training data
x_train = sc.fit_transform(x_train)

# transform testing data
x_test = sc.transform(x_test)

# %%
x_train
# Out:
# array([[ 1.0007622 ,  0.3622324 , -0.1092459 , ...,  0.89771376,
#          1.81912069,  0.6093371 ],
#        [ 1.0007622 , -1.04904084, -0.1092459 , ...,  0.05721134,
#         -0.46950515,  0.22595313],
#        [ 1.0007622 ,  0.83265681, -0.53006473, ...,  0.29735489,
#          1.92314914,  0.48154244],
#        ...,
#        [ 1.0007622 , -0.40220727, -0.6002012 , ...,  0.77764199,
#          1.09092156,  0.73713176],
#        [ 1.0007622 ,  0.77385376, -0.74047414, ..., -0.30300398,
#         -0.15741981, -0.15743085],
#        [-0.99923839, -0.87263168, -0.6002012 , ..., -1.6237935 ,
#         -2.44604565, -2.58552934]])

# %%
x_test
# Out:
# array([[ 1.0007622 , -0.93143473, -0.31965532, ..., -0.78329108,
#         -0.15741981, -0.2852255 ],
#        [-0.99923839, -0.87263168,  1.15321058, ..., -1.1435064 ,
#         -1.40576118, -0.92419879],
#        [ 1.0007622 , -0.87263168,  1.5740294 , ...,  0.77764199,
#         -0.05339136,  0.99272107],
#        ...,
#        [-0.99923839, -0.81382863, -0.1092459 , ..., -0.30300398,
#         -0.46950515, -0.02963619],
#        [ 1.0007622 ,  0.12702019, -0.74047414, ..., -0.06286043,
#         -0.78159049,  0.22595313],
#        [-0.99923839,  0.4798385 ,  0.66225528, ..., -1.50372173,
#         -1.61381807, -1.94655605]])

# %%
# Linear Regression

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Create and train the Linear Regression model
model_lr = LinearRegression()
model_lr.fit(x_train, y_train)

# Make predictions
y_pred_lr = model_lr.predict(x_test)

# Calculate performance metrics
mae_lr = mean_absolute_error(y_test, y_pred_lr)
mse_lr = mean_squared_error(y_test, y_pred_lr)
rmse_lr = np.sqrt(mse_lr)
mape_lr = np.mean(np.abs((y_test - y_pred_lr) / np.abs(y_test)))
accuracy_lr = 100 * (1 - mape_lr)

# Print the performance metrics for Linear Regression
print('Linear Regression Metrics:')
print('Mean Absolute Error (MAE):', mae_lr)
print('Mean Squared Error (MSE):', mse_lr)
print('Root Mean Squared Error (RMSE):', rmse_lr)
print('Mean Absolute Percentage Error (MAPE):', round(mape_lr * 100, 2))
print('Accuracy:', round(accuracy_lr, 2))
# Out:
# Linear Regression Metrics:
# Mean Absolute Error (MAE): 8.266244430607793
# Mean Squared Error (MSE): 122.62584428590661
# Root Mean Squared Error (RMSE): 11.073655416614091
# Mean Absolute Percentage Error (MAPE): 28.23
# Accuracy: 71.77

# %%
#Random forest 

from sklearn.ensemble import RandomForestRegressor

# Create and train the Random Forest model
model_rf = RandomForestRegressor(n_estimators=100, random_state=42)
model_rf.fit(x_train, y_train)

# Make predictions
y_pred_rf = model_rf.predict(x_test)

# Calculate performance metrics
mae_rf = mean_absolute_error(y_test, y_pred_rf)
mse_rf = mean_squared_error(y_test, y_pred_rf)
rmse_rf = np.sqrt(mse_rf)
mape_rf = np.mean(np.abs((y_test - y_pred_rf) / np.abs(y_test)))
accuracy_rf = 100 * (1 - mape_rf)

# Print the performance metrics for Random Forest
print('Random Forest Metrics:')
print('Mean Absolute Error (MAE):', mae_rf)
print('Mean Squared Error (MSE):', mse_rf)
print('Root Mean Squared Error (RMSE):', rmse_rf)
print('Mean Absolute Percentage Error (MAPE):', round(mape_rf * 100, 2))
print('Accuracy:', round(accuracy_rf, 2))
# Out:
# Random Forest Metrics:
# Mean Absolute Error (MAE): 1.8892111111111112
# Mean Squared Error (MSE): 8.7575642
# Root Mean Squared Error (RMSE): 2.9593181985045134
# Mean Absolute Percentage Error (MAPE): 2.92
# Accuracy: 97.08

# %%
from sklearn.tree import DecisionTreeRegressor

# Create and train the Decision Tree model
model = DecisionTreeRegressor()
model.fit(x_train, y_train)

# Make predictions
y_pred = model.predict(x_test)

# Calculate performance metrics
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mape = np.mean(np.abs((y_test - y_pred) / np.abs(y_test)))
accuracy = 100 * (1 - mape)

# Print the performance metrics
print('Mean Absolute Error (MAE):', mae)
print('Mean Squared Error (MSE):', mse)
print('Root Mean Squared Error (RMSE):', rmse)
print('Mean Absolute Percentage Error (MAPE):', round(mape * 100, 2))
print('Accuracy:', round(accuracy, 2))
# Out:
# Mean Absolute Error (MAE): 3.389777777777778
# Mean Squared Error (MSE): 27.32888888888889
# Root Mean Squared Error (RMSE): 5.227703978697425
# Mean Absolute Percentage Error (MAPE): 4.64
# Accuracy: 95.36

# %%
# Cross validation for our model
from sklearn.model_selection import ShuffleSplit, cross_val_score
model=LinearRegression()
ssplit=ShuffleSplit(n_splits=10,test_size=0.30)
from sklearn.model_selection import cross_val_score
results=cross_val_score(model,x,y,cv=ssplit)
print(results)
print("\nMean Cross-validation Accuracy:",np.mean(results))
# Out:
# [0.9674559  0.9669418  0.96798092 0.96711509 0.96802233 0.9682914
#  0.96751483 0.96710124 0.96658378 0.96761443]
#
# Mean Cross-validation Accuracy: 0.9674621723120229

# %%
# Cross validation for our model
model=DecisionTreeRegressor(max_depth=3)
ssplit=ShuffleSplit(n_splits=10,test_size=0.30)
from sklearn.model_selection import cross_val_score
results=cross_val_score(model,x,y,cv=ssplit)
print(results)
print("\nMean Cross-validation Accuracy:",np.mean(results))
# Out:
# [0.91985557 0.91896988 0.92073241 0.92125891 0.92101725 0.92124283
#  0.91984565 0.92452061 0.9220569  0.91958509]
#
# Mean Cross-validation Accuracy: 0.920908510451015

# %%
import xgboost as xgb

# Create and train the XGBoost model
model_xgb = xgb.XGBRegressor()
model_xgb.fit(x_train, y_train)

# Make predictions
y_pred_xgb = model_xgb.predict(x_test)

# Calculate performance metrics
mae_xgb = mean_absolute_error(y_test, y_pred_xgb)
mse_xgb = mean_squared_error(y_test, y_pred_xgb)
rmse_xgb = np.sqrt(mse_xgb)
mape_xgb = np.mean(np.abs((y_test - y_pred_xgb) / np.abs(y_test)))
accuracy_xgb = 100 * (1 - mape_xgb)

# Print the performance metrics for XGBoost
print('XGBoost Metrics:')
print('Mean Absolute Error (MAE):', mae_xgb)
print('Mean Squared Error (MSE):', mse_xgb)
print('Root Mean Squared Error (RMSE):', rmse_xgb)
print('Mean Absolute Percentage Error (MAPE):', round(mape_xgb * 100, 2))
print('Accuracy:', round(accuracy_xgb, 2))
# Out:
# XGBoost Metrics:
# Mean Absolute Error (MAE): 1.467831633117464
# Mean Squared Error (MSE): 4.430165822287355
# Root Mean Squared Error (RMSE): 2.1047959098894493
# Mean Absolute Percentage Error (MAPE): 2.53
# Accuracy: 97.47

# %%
model_xgb = xgb.XGBRegressor(objective='reg:squarederror', random_state=42)

# Define ShuffleSplit cross-validation
ssplit = ShuffleSplit(n_splits=10, test_size=0.3)

# Perform cross-validation
results_xgb = cross_val_score(model_xgb, x, y, cv=ssplit)

# Print results for each fold
print("Cross-validation results for each fold:")
print(results_xgb)

# Print mean accuracy across all folds
print("\nMean Cross-validation Accuracy:", np.mean(results_xgb))
# Out:
# Cross-validation results for each fold:
# [0.99872458 0.99887934 0.99860177 0.99862063 0.99867589 0.99884529
#  0.99866265 0.99890762 0.99868955 0.99862672]
#
# Mean Cross-validation Accuracy: 0.9987234044158336

# %%
# Add a dummy value (like 0) for the missing 8th feature
#user_id = 0  # or some default value depending on your dataset
#input_data = np.array([[gender, age, height, weight, duration, heart_rate, body_temp, user_id]])

# %%
# Add a dummy feature (e.g., `user_id = 0`) to make the input array have 8 features
#user_id = 0  # or set it to any default value that your model expects
#input_data = np.array([[gender, age, height, weight, duration, heart_rate, body_temp, user_id]])

# Now scale the data
#input_data_scaled = scaler.transform(input_data)

# Predict using the model
#prediction = model.predict(input_data_scaled)

# %%
import pickle
from xgboost import XGBRegressor

# Example: Train a model (XGBoost Regressor as an example)
model_xgb = XGBRegressor()
model_xgb.fit(x_train, y_train)

# Save the trained model to a file using pickle
with open('Calories.pkl', 'wb') as file:
    pickle.dump(model_xgb, file)

print("Model saved successfully.")
# Out:
# Model saved successfully.

# %%
with open('schr.pkl', 'wb') as scaler_file:
    pickle.dump(sc, scaler_file)

# %%
import tkinter as tk
import pickle
import numpy as np
from tkinter import messagebox

# Load the trained XGBoost model and scaler
with open('Calories.pkl', 'rb') as model_file:
    model = pickle.load(model_file)

with open('schr.pkl', 'rb') as scaler_file:
    scaler = pickle.load(scaler_file)

# Create Tkinter GUI
root = tk.Tk()
root.title("Calories Prediction")

# Function to get prediction from input fields
def get_prediction():
    try:
        # Get input values from entry fields
        gender = gender_entry.get().strip()
        age = age_entry.get().strip()
        height = height_entry.get().strip()
        weight = weight_entry.get().strip()
        duration = duration_entry.get().strip()
        heart_rate = heart_rate_entry.get().strip()
        body_temp = body_temp_entry.get().strip()

        # Check if any field is empty
        if not all([gender, age, height, weight, duration, heart_rate, body_temp]):
            messagebox.showerror("Invalid Input", "All fields are required.")
            return

        # Convert the input values to the expected data types
        try:
            gender = int(gender)
            if gender not in [0, 1]:
                raise ValueError("Gender must be either 0 (Male) or 1 (Female).")
        except ValueError as e:
            messagebox.showerror("Invalid Input", f"Invalid gender value: {e}")
            return

        try:
            age = int(age)
            height = float(height)
            weight = float(weight)
            duration = float(duration)
            heart_rate = float(heart_rate)
            body_temp = float(body_temp)
        except ValueError:
            messagebox.showerror("Invalid Input", "Please enter numeric values for all fields.")
            return

        # Validate inputs (e.g., positive values)
        if age <= 0 or height <= 0 or weight <= 0 or duration < 0 or heart_rate <= 0 or body_temp <= 0:
            messagebox.showerror("Invalid Input", "Please enter valid values:\nAge, Height, Weight > 0, Duration >= 0, Heart Rate > 0, Body Temp > 0.")
            return

        # Create a numpy array with input values (adding gender as the first feature)
        input_data = np.array([[gender, age, height, weight, duration, heart_rate, body_temp]])

        # Normalize the input data using the scaler
        input_data_scaled = scaler.transform(input_data)

        # Predict using the loaded model
        prediction = model.predict(input_data_scaled)

        # Display prediction result
        result_label.config(text=f"Predicted Calories Burned: {prediction[0]:,.2f} kcal")

    except Exception as e:
        messagebox.showerror("Error", f"An error occurred: {str(e)}")

# Create labels and entry fields for input features
tk.Label(root, text="Gender (0=Male, 1=Female)").grid(row=0, column=0)
tk.Label(root, text="Age (years)").grid(row=1, column=0)
tk.Label(root, text="Height (cm)").grid(row=2, column=0)
tk.Label(root, text="Weight (kg)").grid(row=3, column=0)
tk.Label(root, text="Duration (minutes)").grid(row=4, column=0)
tk.Label(root, text="Heart Rate (bpm)").grid(row=5, column=0)
tk.Label(root, text="Body Temperature (°C)").grid(row=6, column=0)

gender_entry = tk.Entry(root)
age_entry = tk.Entry(root)
height_entry = tk.Entry(root)
weight_entry = tk.Entry(root)
duration_entry = tk.Entry(root)
heart_rate_entry = tk.Entry(root)
body_temp_entry = tk.Entry(root)

gender_entry.grid(row=0, column=1)
age_entry.grid(row=1, column=1)
height_entry.grid(row=2, column=1)
weight_entry.grid(row=3, column=1)
duration_entry.grid(row=4, column=1)
heart_rate_entry.grid(row=5, column=1)
body_temp_entry.grid(row=6, column=1)

# Button to trigger prediction
predict_button = tk.Button(root, text="Predict", command=get_prediction)
predict_button.grid(row=7, columnspan=2)

# Label to display prediction result
result_label = tk.Label(root, text="")
result_label.grid(row=8, columnspan=2)

root.mainloop()
# Out:
# C:\Users\singh\OneDrive\Documents\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # App

# %%
streamlit_code = """
import streamlit as st
import pickle
import numpy as np

# Load the trained XGBoost model and scaler
with open('Calories.pkl', 'rb') as model_file:
    model = pickle.load(model_file)

with open('schr.pkl', 'rb') as scaler_file:
    scaler = pickle.load(scaler_file)

# Title of the web app
st.title("Calories Burned Prediction App")

# Input fields
st.write("### Enter the required inputs:")
gender = st.radio("Gender", options=["Male", "Female"])
age = st.number_input("Age (years)", min_value=1, max_value=120, value=25, step=1)
height = st.number_input("Height (cm)", min_value=50.0, max_value=250.0, value=170.0, step=0.1)
weight = st.number_input("Weight (kg)", min_value=20.0, max_value=200.0, value=70.0, step=0.1)
duration = st.number_input("Duration of Exercise (minutes)", min_value=0.0, max_value=300.0, value=30.0, step=1.0)
heart_rate = st.number_input("Heart Rate (bpm)", min_value=30.0, max_value=220.0, value=75.0, step=0.1)
body_temp = st.number_input("Body Temperature (°C)", min_value=30.0, max_value=45.0, value=36.5, step=0.1)

# Convert gender to numeric encoding
gender_encoded = 0 if gender == "Male" else 1

# Prediction logic
if st.button("Predict Calories Burned"):
    try:
        # Create feature vector
        input_data = np.array([[gender_encoded, age, height, weight, duration, heart_rate, body_temp]])

        # Normalize the input data using the scaler
        input_data_scaled = scaler.transform(input_data)

        # Predict calories burned
        prediction = model.predict(input_data_scaled)

        # Display the result
        st.success(f"Predicted Calories Burned: {prediction[0]:,.2f} kcal")
    except Exception as e:
        st.error(f"An error occurred: {str(e)}")
    """

# Specify the file path where the hrapp.py file will be saved
file_path = 'Caloriespredcition.py'

# Write the content to the file
with open(file_path, 'w') as file:
    file.write(streamlit_code)

print(f"File '{file_path}' has been saved.")
# Out:
# File 'Caloriespredcition.py' has been saved.
